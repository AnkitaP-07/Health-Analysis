# %% [markdown]
# ## Health Care Analysis

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.preprocessing import LabelEncoder as le
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read the file

# %%
import pandas as pd
healdf1 = pd.read_csv("C:\\Users\\Admin\\Desktop\\ShaliniMam_edu\\healthdata.csv")
healdf1
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# ### To know the dimension

# %%
healdf1.ndim
# Out:
# 2

# %% [markdown]
# ### Getting the no. of rows and columns in df

# %%
healdf1.shape
# Out:
# (5110, 12)

# %% [markdown]
# ### Top 5 records.

# %%
healdf1.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Bottom 5 data records.

# %%
healdf1.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %% [markdown]
# ### Columns present in the Dataframe

# %%
col_count = healdf1.columns
col_count = pd.Series(col_count)
col_count
# Out:
# 0                    id
# 1                gender
# 2                   age
# 3          hypertension
# 4         heart_disease
# 5          ever_married
# 6             work_type
# 7        Residence_type
# 8     avg_glucose_level
# 9                   bmi
# 10       smoking_status
# 11               stroke
# dtype: object

# %% [markdown]
# ### To know what type of Data types are present in the DF

# %%
healdf1.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# ### Information about the DF

# %%
healdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# ### Statistical information about the DF

# %%
healdf1.describe(include = 'all')
# Out:
#                   id  gender          age  hypertension  heart_disease  \
# count    5110.000000    5110  5110.000000   5110.000000    5110.000000
# unique           NaN       3          NaN           NaN            NaN
# top              NaN  Female          NaN           NaN            NaN
# freq             NaN    2994          NaN           NaN            NaN
# mean    36517.829354     NaN    43.226614      0.097456       0.054012
# std     21161.721625     NaN    22.612647      0.296607       0.226063
# min        67.000000     NaN     0.080000      0.000000       0.000000
# 25%     17741.250000     NaN    25.000000      0.000000       0.000000
# 50%     36932.000000     NaN    45.000000      0.000000       0.000000
# 75%     54682.000000     NaN    61.000000      0.000000       0.000000
# max     72940.000000     NaN    82.000000      1.000000       1.000000
#
#        ever_married work_type Residence_type  avg_glucose_level          bmi  \
# ...

# %% [markdown]
# ### Getting the unique records in the DF

# %%
healdf1.nunique()
# Out:
# id                   5110
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %% [markdown]
# ## Cleaning the Data.

# %% [markdown]
# #### Getting the null values.

# %%
healdf1.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# #### Deleting the unwanted columns

# %%
df = healdf1.drop(['ever_married' ,'Residence_type' ], axis = 1)
df
# Out:
#          id  gender   age  hypertension  heart_disease      work_type  \
# 0      9046    Male  67.0             0              1        Private
# 1     51676  Female  61.0             0              0  Self-employed
# 2     31112    Male  80.0             0              1        Private
# 3     60182  Female  49.0             0              0        Private
# 4      1665  Female  79.0             1              0  Self-employed
# ...     ...     ...   ...           ...            ...            ...
# 5105  18234  Female  80.0             1              0        Private
# 5106  44873  Female  81.0             0              0  Self-employed
# 5107  19723  Female  35.0             0              0  Self-employed
# 5108  37544    Male  51.0             0              0        Private
# 5109  44679  Female  44.0             0              0       Govt_job
#
#       avg_glucose_level   bmi   smoking_status  stroke
# 0                228.69  36.6  formerly smoked       1
# ...

# %% [markdown]
# ## Relationship Analysis

# %% [markdown]
# #### Correlation Analysis:
# Corr() is used to summarize the data as an in input to more advanced analysis and also as a diagnostic for more advanced analysis

# %%
correlation = df.corr()

# %%
sns.heatmap(correlation , xticklabels=correlation.columns, yticklabels=correlation.columns , annot= True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Visualizing the Dataframe using pairplot()
# Pairplot () is used to visualize the relationship between the variables , and the variable may be of categorical , continuous or boolean.

# %%
sns.pairplot(df)

# %% [markdown]
# ### Plotting the distribution plot for showing the result for age.

# %%
sns.distplot(df[ 'bmi'] , bins = 10)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %% [markdown]
# ### Categorical plot for glucose level.

# %%
sns.catplot(x = 'avg_glucose_level' , kind = 'box' , data = df )

# %% [markdown]
# ### Getting the different work type.

# %%
work_sector= df['work_type'].value_counts()
work_sector

##do factorization for work type
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %% [markdown]
# ### Plotting the bar graph for different sectors.

# %%
style.use('ggplot')
plt.figure(figsize = (10,6))
work_sector.plot.barh()
# Out:
# <AxesSubplot:>

# %%
worktype = df.loc[:,['id', 'age', 'gender' , 'work_type' , 'heart_disease' , 'hypertension' , 'smoking_status']]
worktype.head()
# Out:
#       id   age  gender      work_type  heart_disease  hypertension  \
# 0   9046  67.0    Male        Private              1             0
# 1  51676  61.0  Female  Self-employed              0             0
# 2  31112  80.0    Male        Private              1             0
# 3  60182  49.0  Female        Private              0             0
# 4   1665  79.0  Female  Self-employed              0             1
#
#     smoking_status
# 0  formerly smoked
# 1     never smoked
# 2     never smoked
# 3           smokes
# 4     never smoked

# %% [markdown]
# **0 for Govt Sector**
#
# **1 for Never Worked**
#
# **2 for Private Sector**
#
# **3 for Selfemployed**
#
# **4 for Childern**

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()
df['sector'] = le.fit_transform(df.work_type)

# %%
df['sector'] = le.fit_transform(df.work_type)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'gender' , y = 'age' , hue = 'sector' , data = df )
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
### Do factorization for the smoking status
smokers = df.loc[:, ['age' , 'gender' ,'smoking_status' , 'avg_glucose_level','bmi' ]]
smokers
# Out:
#        age  gender   smoking_status  avg_glucose_level   bmi
# 0     67.0    Male  formerly smoked             228.69  36.6
# 1     61.0  Female     never smoked             202.21   NaN
# 2     80.0    Male     never smoked             105.92  32.5
# 3     49.0  Female           smokes             171.23  34.4
# 4     79.0  Female     never smoked             174.12  24.0
# ...    ...     ...              ...                ...   ...
# 5105  80.0  Female     never smoked              83.75   NaN
# 5106  81.0  Female     never smoked             125.20  40.0
# 5107  35.0  Female     never smoked              82.99  30.6
# 5108  51.0    Male  formerly smoked             166.29  25.6
# 5109  44.0  Female          Unknown              85.28  26.2
#
# [5110 rows x 5 columns]

# %% [markdown]
# #### Changing the categorical value ie smoking status into numeric value.

# %%
# Using the above DF 'smokers' , we factorize the somking status , and created a column name 'who_smokes', 
# which give the numeric counts , who smokes denotes as '2' and so on.


le = LabelEncoder()
smokers['who_smokes'] = le.fit_transform(df.smoking_status)
smokers.head(5)
# Out:
#     age  gender   smoking_status  avg_glucose_level   bmi  who_smokes
# 0  67.0    Male  formerly smoked             228.69  36.6           1
# 1  61.0  Female     never smoked             202.21   NaN           2
# 2  80.0    Male     never smoked             105.92  32.5           2
# 3  49.0  Female           smokes             171.23  34.4           3
# 4  79.0  Female     never smoked             174.12  24.0           2

# %% [markdown]
# ### **For Smokers Code**
#
# **0 for Unknown**
#
# **1 for Formerly smoked**
#
# **2 for Never Smoked**
#
# **3 for Smokes**

# %%
plt.figure(figsize =(10, 6))
sns.catplot( x = 'age' , y = 'gender' ,kind = 'swarm', hue = 'who_smokes'  ,data = smokers)

# %% [markdown]
# ### Extracting the records of the person who smokes and is less than or equals to 25 years of age

# %%
age_25 = df.loc[(healdf1['smoking_status']!= 'never smokes') & (df['age']<= 25)]
age_25[['id' ,'smoking_status' , 'age' , 'gender']].head(10)
# Out:
#         id smoking_status    age  gender
# 162  69768        Unknown   1.32  Female
# 245  49669        Unknown  14.00  Female
# 249  30669        Unknown   3.00    Male
# 251  16523        Unknown   8.00  Female
# 253  46136        Unknown  14.00    Male
# 265  19584         smokes  20.00  Female
# 274  70336   never smoked  25.00  Female
# 282  33759        Unknown   3.00  Female
# 284  26325        Unknown  14.00    Male
# 286  36811   never smoked  23.00  Female

# %%
smoke_st = age_25.groupby('smoking_status').count()
smoke_st
# Out:
#                   id  gender  age  hypertension  heart_disease  work_type  \
# smoking_status
# Unknown          803     803  803           803            803        803
# formerly smoked   62      62   62            62             62         62
# never smoked     346     346  346           346            346        346
# smokes            82      82   82            82             82         82
#
#                  avg_glucose_level  bmi  stroke  sector
# smoking_status
# Unknown                        803  786     803     803
# formerly smoked                 62   60      62      62
# never smoked                   346  342     346     346
# smokes                          82   76      82      82

# %% [markdown]
# ### Plotting Scatter plot
#
# Scatterplot shows the relationship between the numerical values,

# %%
sns.scatterplot(x = 'bmi' , y = 'age' , hue = 'gender' , data = df)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='age'>

# %% [markdown]
# ### Showing the Violin plot for Gender and their respective age in the dataset

# %%
sns.violinplot(x = 'gender' , y = 'age' , data = healdf1)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %% [markdown]
# ### Extracting records of person below 25 , suffering from heart anomilities

# %%
age_25 = healdf1.loc[healdf1['heart_disease']==1]
age_25
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0      9046    Male  67.0             0              1          Yes   Private
# 2     31112    Male  80.0             0              1          Yes   Private
# 6     53882    Male  74.0             1              1          Yes   Private
# 11    12095  Female  61.0             0              1          Yes  Govt_job
# 13     8213    Male  78.0             0              1          Yes   Private
# ...     ...     ...   ...           ...            ...          ...       ...
# 4855  42563  Female  57.0             1              1          Yes   Private
# 4869  72715  Female  50.0             0              1          Yes   Private
# 4921   4062    Male  72.0             0              1          Yes   Private
# 4986  53697    Male  58.0             0              1          Yes   Private
# 5008  48109  Female  79.0             0              1          Yes   Private
#
# ...

# %% [markdown]
# ### Extracting the record whose age is less than 25 and suffering from Hypertension.

# %%
age_hyp = age_25.loc[(age_25['hypertension']==1)]
age_hyp[['age' , 'hypertension' ]]
# Out:
#        age  hypertension
# 6     74.0             1
# 35    82.0             1
# 115   71.0             1
# 143   69.0             1
# 171   79.0             1
# ...    ...           ...
# 4590  82.0             1
# 4638  72.0             1
# 4684  78.0             1
# 4784  81.0             1
# 4855  57.0             1
#
# [64 rows x 2 columns]

# %% [markdown]
# ### Extracting the records, who has smoked formerly , and is suffering from either hypertension or heart disease.

# %%
smoke = healdf1.loc[(healdf1['smoking_status'] == 'formerly smoked') &
                   (healdf1['hypertension'] == 1) | (healdf1['heart_disease'] == 1)]
smokers = smoke[['smoking_status' , 'hypertension' , 'heart_disease']]
smokers
# Out:
#        smoking_status  hypertension  heart_disease
# 0     formerly smoked             0              1
# 2        never smoked             0              1
# 6        never smoked             1              1
# 11             smokes             0              1
# 13            Unknown             0              1
# ...               ...           ...            ...
# 4855  formerly smoked             1              1
# 4869     never smoked             0              1
# 4921           smokes             0              1
# 4986           smokes             0              1
# 5008     never smoked             0              1
#
# [375 rows x 3 columns]

# %% [markdown]
# ### Showing the voilin plot for the person suffering from hypertension and heart disease

# %%
import seaborn as sns
hyp = healdf1['hypertension']
hrt = healdf1['heart_disease']
x = list(hyp)
y = list(hrt)



sns.violinplot(x,y,
                sizes=(1, 8), linewidth=2,
                data=healdf1)
plt.xlabel('heart->')
plt.ylabel('hyper tension ->')
plt.title('Suffering from Hypertension and Heart Disease')
plt.show()

# %% [markdown]
# ### Extracting the records of total number of Independent Female

# %%
F_work = healdf1.loc[(healdf1['gender' ]=='Female') ]
F_work.loc[: ,['age' , 'gender' , 'work_type']]
# Out:
#        age  gender      work_type
# 1     61.0  Female  Self-employed
# 3     49.0  Female        Private
# 4     79.0  Female  Self-employed
# 7     69.0  Female        Private
# 8     59.0  Female        Private
# ...    ...     ...            ...
# 5104  13.0  Female       children
# 5105  80.0  Female        Private
# 5106  81.0  Female  Self-employed
# 5107  35.0  Female  Self-employed
# 5109  44.0  Female       Govt_job
#
# [2994 rows x 3 columns]

# %% [markdown]
# ### Record of total number of obese person

# %%
total_obese = healdf1.loc[healdf1['bmi']>=30]
a = total_obese.value_counts()
obese = a.sum()
print("The total number of Obese person are: ",obese)
# Out:
# The total number of Obese person are:  1920

# %% [markdown]
# ### Extracting BMI report for below 30 and have Healthy weight.

# %%
below_bmi30 = healdf1.loc[healdf1['age'].between(18, 30, inclusive=True) 
                    & healdf1['bmi'].between(18.5 , 24.9 , inclusive = True)]

below_bmi30[['gender' , 'age' ,'ever_married','work_type', 'Residence_type']]
# Out:
#       gender   age ever_married work_type Residence_type
# 265   Female  20.0           No   Private          Urban
# 274   Female  25.0          Yes   Private          Urban
# 312   Female  27.0          Yes   Private          Rural
# 322   Female  22.0           No   Private          Urban
# 324     Male  27.0           No  Govt_job          Urban
# ...      ...   ...          ...       ...            ...
# 5058    Male  21.0           No   Private          Rural
# 5067    Male  21.0           No   Private          Urban
# 5073  Female  24.0           No   Private          Urban
# 5083  Female  19.0           No   Private          Urban
# 5090    Male  26.0           No  Govt_job          Rural
#
# [277 rows x 5 columns]

# %% [markdown]
# ### Extracting BMI report for 30+ and have Healthy weight.

# %%
abv_bmi30 = healdf1.loc[healdf1['age'].between(30, 90, inclusive=True) 
                    & healdf1['bmi'].between(18.5 , 24.9 , inclusive = True)]

abv_bmi30[['gender' , 'age' ,'ever_married','work_type', 'Residence_type']]
# Out:
#       gender   age ever_married      work_type Residence_type
# 4     Female  79.0          Yes  Self-employed          Rural
# 7     Female  69.0           No        Private          Urban
# 9     Female  78.0          Yes        Private          Urban
# 20    Female  71.0          Yes       Govt_job          Rural
# 25      Male  80.0          Yes  Self-employed          Rural
# ...      ...   ...          ...            ...            ...
# 5068    Male  80.0          Yes  Self-employed          Urban
# 5076  Female  34.0          Yes        Private          Rural
# 5086  Female  51.0          Yes        Private          Urban
# 5101  Female  45.0          Yes        Private          Urban
# 5102  Female  57.0          Yes        Private          Rural
#
# [603 rows x 5 columns]

# %% [markdown]
# ### Records of total numbers Female who have Healthy weight

# %%
heal_fe= abv_bmi30.loc[abv_bmi30['gender']=='Female']
heal_fe[['age' , 'gender']]
healthy_f = heal_fe.value_counts()
tot_h_f = healthy_f.sum()
print("Total number of Normal weighted Female are : ",tot_h_f)
# Out:
# Total number of Normal weighted Female are :  455

# %% [markdown]
# ### Records of total numbers Male who have Healthy weight

# %%
heal_M= abv_bmi30.loc[abv_bmi30['gender']=='Male']
heal_M[['age' , 'gender']]
healthy_M = heal_M.value_counts()
tot_h_M = healthy_M.sum()
print("Total number of Normal weighted Male are : ",tot_h_M)
# Out:
# Total number of Normal weighted Male are :  148

# %% [markdown]
# ### Average BMI who are 40+

# %%
bmi_lvl = abv_bmi30.bmi.sum()
print bmi_lvl
# Out:
# 13710.6

# %% [markdown]
# ### Total number of children (below 18) and are working

# %%
childern = healdf1.loc[(healdf1['age']<=18) & 
                      (healdf1['work_type'] != 'Never_worked')]
work_child = childern[['age' , 'work_type']]
work_child
# Out:
#         age work_type
# 162    1.32  children
# 245   14.00  children
# 249    3.00  children
# 251    8.00   Private
# 282    3.00  children
# ...     ...       ...
# 5094  13.00  children
# 5095   1.08  children
# 5098   9.00  children
# 5103  18.00   Private
# 5104  13.00  children
#
# [896 rows x 2 columns]

# %% [markdown]
# ### Child marriage

# %%
child_mar = healdf1.loc[(healdf1['age']<=18) & (healdf1['ever_married'] == 'Yes')]
child_mar
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 1169  39661   Male  18.0             0              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 1169          Rural             140.52  27.4   never smoked       0

# %% [markdown]
# ### Extracting the report for the person who is 40+ and got stroke

# %%
age40 = healdf1.loc[(healdf1['age']>=40) & (healdf1['smoking_status']) ]
stroke40 = age40.loc[age40['stroke'] ==1]
stroke40.loc[:,['age' , 'stroke' , 'heart_disease']].head(20)
# Out:
#      age  stroke  heart_disease
# 0   67.0       1              1
# 1   61.0       1              0
# 2   80.0       1              1
# 3   49.0       1              0
# 4   79.0       1              0
# 5   81.0       1              0
# 6   74.0       1              1
# 7   69.0       1              0
# 8   59.0       1              0
# 9   78.0       1              0
# 10  81.0       1              0
# 11  61.0       1              1
# 12  54.0       1              0
# 13  78.0       1              1
# 14  79.0       1              1
# 15  50.0       1              0
# 16  64.0       1              1
# 17  75.0       1              0
# 18  60.0       1              0
# 19  57.0       1              1

# %% [markdown]
# ### Extracting the report of the employee who live in Urban area

# %%
residence = healdf1.loc[healdf1['Residence_type'] == 'Urban']
residence
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# 7     10434  Female  69.0             0              0           No
# 9     60491  Female  78.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5101  36901  Female  45.0             0              0          Yes
# 5103  22127  Female  18.0             0              0           No
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# ### Extracting the record for 60+ persons

# %%
rep_60 = healdf1.loc[healdf1['age']>=60].head()
rep_60
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 4   1665  Female  79.0             1              0          Yes
# 5  56669    Male  81.0             0              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 4  Self-employed          Rural             174.12  24.0     never smoked
# 5        Private          Urban             186.21  29.0  formerly smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 4       1
# 5       1

# %% [markdown]
# ### Extracting report of male above 60+

# %%
M_60 = rep_60.loc[rep_60['gender'] == 'Male']
M_60
# Out:
#       id gender   age  hypertension  heart_disease ever_married work_type  \
# 0   9046   Male  67.0             0              1          Yes   Private
# 2  31112   Male  80.0             0              1          Yes   Private
# 5  56669   Male  81.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 5          Urban             186.21  29.0  formerly smoked       1

# %%
F_60 = healdf1.loc[healdf1['gender'] == 'Female']
F_60
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 1     51676  Female  61.0             0              0          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 7     10434  Female  69.0             0              0           No
# 8     27419  Female  59.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
age_df = healdf1.loc[(healdf1['age'] >=23) & (healdf1['age']<=80)]
age = age_df.loc[(age_df['hypertension']==1 ) & (age_df['stroke']==1 )]
age.loc[:, ['age' , 'hypertension' , 'stroke' ]].value_counts()
# Out:
# age   hypertension  stroke
# 80.0  1             1         7
# 78.0  1             1         7
# 79.0  1             1         4
# 68.0  1             1         4
# 76.0  1             1         3
# 57.0  1             1         3
# 72.0  1             1         3
# 69.0  1             1         2
# 50.0  1             1         2
# 51.0  1             1         2
# 61.0  1             1         2
# 67.0  1             1         2
# 70.0  1             1         2
# 71.0  1             1         2
# 73.0  1             1         2
# 74.0  1             1         2
# 77.0  1             1         2
# 66.0  1             1         1
# 60.0  1             1         1
# 56.0  1             1         1
# 55.0  1             1         1
# 54.0  1             1         1
# 53.0  1             1         1
# 52.0  1             1         1
# 75.0  1             1         1
# 39.0  1             1         1
# dtype: int64

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In the "Health Care Analysis" , i have concluded how many person have heart disease and suffering from hypertension and in what age group. Person who smoked and have some kind of serious problems with them , their glucose level and BMI's. Also, i have concluded that how many are there who are married below 18 year of age i.e. the child marriage, how many person are working as child workers.

# %% [markdown]
# ### Reference

# %% [markdown]
# I took reference from kaggle.com , also sharing the link below.
# https://www.kaggle.com/fedesoriano/stroke-prediction-dataset
#
# I also took help of some  Youtube channels, to get the queries so i can extract the exact data i want.
